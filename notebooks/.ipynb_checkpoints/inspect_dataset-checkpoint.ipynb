# %% [markdown]
# # Verify dataset generated by rmpe_dataset_transformer

# %% [markdown]
# # Verify data generator client

# %%
# %matplotlib inline
import matplotlib.pyplot  as plt
import cv2
import sys
sys.path.append('..')
from src.train.ds_generator_client import DataGeneratorClient
client = DataGeneratorClient(port=5555, host="localhost", hwm=1, batch_size=10)
client.restart()
batch_index = 0

# %%
x,y = next(client.gen())

# %%
len(y)
# Out:
# 12

# %%
print(x[0].shape)
print(x[1].shape)
print(x[2].shape)

print(y[0].shape)
print(y[1].shape)
print(y[2].shape)
print(y[3].shape)
print(y[4].shape)
print(y[5].shape)
print(y[6].shape)
print(y[7].shape)
print(y[8].shape)
print(y[9].shape)
print(y[10].shape)
print(y[11].shape)
# Out:
# (10, 368, 368, 3)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)
# (10, 46, 46, 38)
# (10, 46, 46, 19)

# %% [markdown]
# ## Show orig image

# %%
plt.rcParams['figure.figsize'] = 20, 20
#x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

# %% [markdown]
# # Show orig img + mask

# %%
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

mask_img = x[1][batch_index,:,:,:]
mask_img = cv2.resize(mask_img[:,:, 0], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)


plt.imshow(mask_img * 255, cmap='gray', alpha=.5)

# %% [markdown]
# # Show heatmap

# %%
batch_index =0
body_part =2


x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

heatmap = cv2.resize(y[1][batch_index, :, :, body_part], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(heatmap[:,:], alpha=.5)

# %% [markdown]
# ## Show PAF

# %%
batch_index = 0
paf_idx = 8
#x,y = next(client.gen())
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

paf = cv2.resize(y[2][batch_index, :, :, paf_idx], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(paf[:,:], alpha=.7)

# %% [raw]
# client.stop()

# %%
val_client = DataGeneratorClient(port=5555, host="localhost", hwm=160, batch_size=10)
val_client.start()
val_di = val_client.gen()

# %%
batch_index =0
body_part = 1
dta_img = x[0][batch_index,:,:,:]
plt.imshow(dta_img[:,:,[2,1,0]])

heatmap = cv2.resize(y[1][batch_index, :, :, body_part], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)

plt.imshow(dta_img[:,:,[2,1,0]])
plt.imshow(heatmap[:,:], alpha=.5)

# %% [markdown]
# y

# %%
U
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=1e+20)

# %%
import numpy as np
from numpy import ma
U =cv2.resize(y[2][batch_index, :, :, 1], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
V =cv2.resize(y[2][batch_index, :, :, 2], (0,0), fx=8, fy=8, interpolation=cv2.INTER_CUBIC)
X, Y = np.meshgrid(np.arange(U.shape[1]), np.arange(U.shape[0]))
#M = np.zeros(U.shape, dtype='bool')
#M[U**2 + V**2 < 0.5 * 0.5] = True
#U = ma.masked_array(U, mask=M)
#V = ma.masked_array(V, mask=M)

# 1
plt.figure()
plt.imshow(dta_img[:,:,[2,1,0]])
s = 5
Q = plt.quiver(X[::s,::s], Y[::s,::s], U[::s,::s], V[::s,::s], 
               scale=10, headaxislength=1, alpha=.5, width=0.0001, color='r')

fig = plt.gcf()
fig.set_size_inches(20, 20)
